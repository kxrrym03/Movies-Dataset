# %% [markdown]
# <a href="https://colab.research.google.com/github/kxrrym03/Movies-Dataset/blob/main/Movies_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-32a8c319-0d70-4f6b-b47c-3c2df76b3db7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32a8c319-0d70-4f6b-b47c-3c2df76b3db7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('movies_dataset.csv')
df.shape
# Out:
# (999999, 17)

# %%
df.head()
# Out:
#    MovieID                         Title        Genre  ReleaseYear  \
# 0        1          Might toward capital       Comedy         2003
# 1        2         He however experience       Comedy         1988
# 2        3  Star responsibility politics       Comedy         1971
# 3        4                  Exactly live       Comedy         1998
# 4        5      Focus improve especially  Documentary         2021
#
#   ReleaseDate Country   BudgetUSD  US_BoxOfficeUSD  Global_BoxOfficeUSD  \
# 0  28-09-2003   China  6577427.79       6613685.82          15472035.66
# 1  14-02-1988     USA  1883810.10       1930949.15           3637731.12
# 2  02-11-1971     USA  2468079.29       4186694.69           7165111.24
# 3  06-08-1998     USA  1447311.46       2023683.92           4373820.26
# 4  17-12-2021   India   900915.86       2129629.10           3113017.38
#
#    Opening_Day_SalesUSD  One_Week_SalesUSD  IMDbRating  RottenTomatoesScore  \
# ...

# %%
df.tail()
# Out:
#         MovieID                              Title        Genre  ReleaseYear  \
# 999994   999995                          He anyone       Action         2011
# 999995   999996  Single yourself sister collection       Horror         1982
# 999996   999997                       Old economic  Documentary         1993
# 999997   999998                My itself and leave       Horror         2013
# 999998   999999            Congress federal policy        Drama         1995
#
#        ReleaseDate Country    BudgetUSD  US_BoxOfficeUSD  Global_BoxOfficeUSD  \
# 999994  14-09-2011   China    648176.38       1075869.51           2624306.41
# 999995  27-08-1982     USA    657167.15       1046949.86           2164587.12
# 999996  12-02-1993     USA  29914685.15      30619499.73          57774787.73
# 999997  11-11-2013   India   1382498.55       3168114.87           5567631.38
# 999998  09-08-1995     USA   7655641.81      18626549.48          34908325.31
#
# ...

# %%
df.isnull().sum()
# Out:
# MovieID                 0
# Title                   0
# Genre                   0
# ReleaseYear             0
# ReleaseDate             0
# Country                 0
# BudgetUSD               0
# US_BoxOfficeUSD         0
# Global_BoxOfficeUSD     0
# Opening_Day_SalesUSD    0
# One_Week_SalesUSD       0
# IMDbRating              0
# RottenTomatoesScore     0
# NumVotesIMDb            0
# NumVotesRT              0
# Director                0
# LeadActor               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999999 entries, 0 to 999998
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   MovieID               999999 non-null  int64
#  1   Title                 999999 non-null  object
#  2   Genre                 999999 non-null  object
#  3   ReleaseYear           999999 non-null  int64
#  4   ReleaseDate           999999 non-null  object
#  5   Country               999999 non-null  object
#  6   BudgetUSD             999999 non-null  float64
#  7   US_BoxOfficeUSD       999999 non-null  float64
#  8   Global_BoxOfficeUSD   999999 non-null  float64
#  9   Opening_Day_SalesUSD  999999 non-null  float64
#  10  One_Week_SalesUSD     999999 non-null  float64
#  11  IMDbRating            999999 non-null  float64
#  12  RottenTomatoesScore   999999 non-null  int64
#  13  NumVotesIMDb          999999 non-null  int64
# ...

# %%
df.describe()
# Out:
#              MovieID    ReleaseYear     BudgetUSD  US_BoxOfficeUSD  \
# count  999999.000000  999999.000000  9.999990e+05     9.999990e+05
# mean   500000.000000    1998.001220  9.802824e+06     1.496163e+07
# std    288674.990255      19.260863  2.249421e+07     3.879403e+07
# min         1.000000    1950.000000  1.000000e+05     4.002547e+04
# 25%    250000.500000    1984.000000  1.190511e+06     1.489805e+06
# 50%    500000.000000    2001.000000  3.265790e+06     4.388876e+06
# 75%    749999.500000    2014.000000  9.002791e+06     1.287606e+07
# max    999999.000000    2025.000000  3.000000e+08     1.018198e+09
#
#        Global_BoxOfficeUSD  Opening_Day_SalesUSD  One_Week_SalesUSD  \
# count         9.999990e+05          9.999990e+05       9.999990e+05
# mean          2.720625e+07          2.992745e+06       7.483442e+06
# std           6.954294e+07          8.132438e+06       1.955337e+07
# min           1.000000e+05          4.050470e+03       1.650742e+04
# ...

# %%
# Group data by ReleaseYear and sum the Global_BoxOfficeUSD
yearly_box_office = df.groupby('ReleaseYear')['Global_BoxOfficeUSD'].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(yearly_box_office['ReleaseYear'], yearly_box_office['Global_BoxOfficeUSD'], marker='o', linestyle='-', alpha=0.8)

# Labels and title
plt.title('Total Global Box Office Revenue by Year', fontsize=16)
plt.xlabel('Release Year', fontsize=14)
plt.ylabel('Global Box Office (USD)', fontsize=14)
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %%
sns.countplot(data=df, x='Genre')
plt.title('Genre Distribution')
plt.xlabel('Genre')
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='Country')
plt.title('Country Distribution')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %%
lead_actor_shows = df['LeadActor'].value_counts().head(10)

plt.figure()
sns.barplot(x=lead_actor_shows.values, y=lead_actor_shows.index, palette="Blues_r")
plt.title("Top 10 Most Successful Lead Actors")
plt.xlabel("Number of Movies")
plt.ylabel("Lead Actor")
plt.show()

# %%
director_shows = df['Director'].value_counts().head(10)

plt.figure()
sns.barplot(x=director_shows.values, y=director_shows.index, palette="Blues_r")
plt.title("Top 10 Most Successful Directors")
plt.xlabel("Number of Movies")
plt.ylabel("Director")
plt.show()
